# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import log_loss

# %%
train=pd.read_csv("data/train.csv")
test=pd.read_csv("data/test.csv")

# %%
train.tail()
# Out:
#       season      date  league_id                             league  \
# 7438    2021  12/12/21       1846               German 2. Bundesliga
# 7439    2021  12/12/21       1846               German 2. Bundesliga
# 7440    2021  14/12/21       1983  South African ABSA Premier League
# 7441    2021  14/12/21       1983  South African ABSA Premier League
# 7442    2021  14/12/21       1983  South African ABSA Premier League
#
#                             Team 1                  Team2   SPI1   SPI2  \
# 7438                 Karlsruher SC  1. FC Heidenheim 1846  34.05  33.76
# 7439                  SC Paderborn        SV Darmstadt 98  36.73  36.11
# 7440               Moroka Swallows        Orlando Pirates  12.97  23.59
# 7441  Tshakhuma Tsha Madzivhandila             Black Aces  11.76  18.07
# 7442             Mamelodi Sundowns              Baroka FC  25.89  10.75
#
#       proj_score1  proj_score2  ...  importance2  score1  score2  xg1  xg2  \
# ...

# %%
test.head()
# Out:
#    season      date  league_id league                    Team 1  \
# 0    2021  14/12/21       2411    BPL                   Arsenal
# 1    2021  14/12/21       2411    BPL  Brighton and Hove Albion
# 2    2021  14/12/21       2411    BPL              Norwich City
# 3    2021  14/12/21       2411    BPL            Leicester City
# 4    2021  14/12/21       2411    BPL                 Brentford
#
#                Team2   SPI1   SPI2  proj_score1  proj_score2  importance1  \
# 0    West Ham United  79.65  74.06         1.67         1.19          NaN
# 1      Wolverhampton  74.19  71.14         1.35         0.98          NaN
# 2        Aston Villa  60.67  71.45         1.18         1.49          NaN
# 3  Tottenham Hotspur  76.88  79.06         1.52         1.44          NaN
# 4  Manchester United  63.53  85.58         0.95         1.92          NaN
#
#    importance2  score1  score2  xg1  xg2  nsxg1  nsxg2  adj_score1  adj_score2
# ...

# %%
features=['season','league_id','Team 1','Team2','SPI1','SPI2','proj_score1','proj_score2']

# %%
train.corr()
# Out:
#                season  league_id      SPI1      SPI2  proj_score1  \
# season       1.000000   0.113254 -0.162314 -0.160489    -0.084619
# league_id    0.113254   1.000000  0.004333  0.005560    -0.087095
# SPI1        -0.162314   0.004333  1.000000  0.735469     0.428690
# SPI2        -0.160489   0.005560  0.735469  1.000000    -0.200509
# proj_score1 -0.084619  -0.087095  0.428690 -0.200509     1.000000
# proj_score2 -0.017207  -0.037132 -0.233199  0.404963    -0.589099
# importance1 -0.233151  -0.171938  0.461272  0.342051     0.254883
# importance2 -0.223965  -0.168781  0.369283  0.457606    -0.090587
# score1      -0.071460  -0.049434  0.130513 -0.113907     0.347064
# score2      -0.071288  -0.060171 -0.040517  0.139575    -0.149661
# xg1         -0.049576  -0.073748  0.166178 -0.074415     0.377380
# xg2         -0.060534  -0.084771 -0.038224  0.185777    -0.218524
# nsxg1       -0.096681  -0.074274  0.148902 -0.108245     0.416531
# ...

# %%
X=train[features]
y=train["Outcome"]
test=test[features]

X.shape,y.shape
# Out:
# ((7443, 8), (7443,))

# %%
X.head()
# Out:
#    season  league_id                Team 1              Team2   SPI1   SPI2  \
# 0    2019       1979       Shandong Luneng      Guizhou Renhe  48.22  37.83
# 1    2019       1979    Shanghai Greenland      Shanghai SIPG  39.81  60.08
# 2    2019       1979  Guangzhou Evergrande  Tianjin Quanujian  65.59  39.99
# 3    2019       1979            Wuhan Zall      Beijing Guoan  32.25  54.82
# 4    2019       1979       Chongqing Lifan       Guangzhou RF  38.24  40.45
#
#    proj_score1  proj_score2
# 0         1.75         0.84
# 1         1.22         1.89
# 2         2.58         0.62
# 3         1.10         1.79
# 4         1.57         1.24

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7443 entries, 0 to 7442
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   season       7443 non-null   int64
#  1   league_id    7443 non-null   int64
#  2   Team 1       7443 non-null   object
#  3   Team2        7443 non-null   object
#  4   SPI1         7443 non-null   float64
#  5   SPI2         7443 non-null   float64
#  6   proj_score1  7443 non-null   float64
#  7   proj_score2  7443 non-null   float64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 465.3+ KB

# %%
X.describe()
# Out:
#             season    league_id         SPI1         SPI2  proj_score1  \
# count  7443.000000  7443.000000  7443.000000  7443.000000  7443.000000
# mean   2020.846702  2264.435980    40.447416    40.486339     1.464127
# std       0.440811  1033.343797    18.367631    18.356843     0.368777
# min    2019.000000  1818.000000     4.710000     4.720000     0.430000
# 25%    2021.000000  1859.000000    28.010000    27.990000     1.220000
# 50%    2021.000000  1948.000000    38.260000    38.290000     1.410000
# 75%    2021.000000  2160.000000    52.160000    52.380000     1.660000
# max    2021.000000  9541.000000    93.990000    94.740000     3.540000
#
#        proj_score2
# count  7443.000000
# mean      1.204017
# std       0.365576
# min       0.200000
# 25%       0.960000
# 50%       1.150000
# 75%       1.390000
# max       3.200000

# %%
X.isna().sum()
# Out:
# season         0
# league_id      0
# Team 1         0
# Team2          0
# SPI1           0
# SPI2           0
# proj_score1    0
# proj_score2    0
# dtype: int64

# %%
object_coloumn=['Team 1','Team2']
trainX=X.copy()
testX=test.copy()
encoder=OrdinalEncoder()
trainX[object_coloumn]=encoder.fit_transform(X[object_coloumn])
testX[object_coloumn]=encoder.transform(test[object_coloumn])

# %%
trainX.corr()
# Out:
#                season  league_id    Team 1     Team2      SPI1      SPI2  \
# season       1.000000   0.113254 -0.037251 -0.038859 -0.162314 -0.160489
# league_id    0.113254   1.000000 -0.016223 -0.014225  0.004333  0.005560
# Team 1      -0.037251  -0.016223  1.000000  0.010010 -0.087554 -0.058577
# Team2       -0.038859  -0.014225  0.010010  1.000000 -0.063102 -0.090451
# SPI1        -0.162314   0.004333 -0.087554 -0.063102  1.000000  0.735469
# SPI2        -0.160489   0.005560 -0.058577 -0.090451  0.735469  1.000000
# proj_score1 -0.084619  -0.087095 -0.037156  0.030389  0.428690 -0.200509
# proj_score2 -0.017207  -0.037132  0.043275 -0.037038 -0.233199  0.404963
#
#              proj_score1  proj_score2
# season         -0.084619    -0.017207
# league_id      -0.087095    -0.037132
# Team 1         -0.037156     0.043275
# Team2           0.030389    -0.037038
# SPI1            0.428690    -0.233199
# SPI2           -0.200509     0.404963
# proj_score1     1.000000    -0.589099
# ...

# %%
# from sklearn.preprocessing import StandardScaler
# scaler=StandardScaler()
# trainX=scaler.fit_transform(trainX)
# testX=scaler.transform(testX)

# %%
testX.head()
# Out:
#    season  league_id  Team 1  Team2   SPI1   SPI2  proj_score1  proj_score2
# 0    2021       2411    40.0  641.0  79.65  74.06         1.67         1.19
# 1    2021       2411   100.0  648.0  74.19  71.14         1.35         0.98
# 2    2021       2411   411.0   45.0  60.67  71.45         1.18         1.49
# 3    2021       2411   333.0  598.0  76.88  79.06         1.52         1.44
# 4    2021       2411    96.0  362.0  63.53  85.58         0.95         1.92

# %%
trainX.head()
# Out:
#    season  league_id  Team 1  Team2   SPI1   SPI2  proj_score1  proj_score2
# 0    2019       1979   531.0  262.0  48.22  37.83         1.75         0.84
# 1    2019       1979   532.0  533.0  39.81  60.08         1.22         1.89
# 2    2019       1979   258.0  589.0  65.59  39.99         2.58         0.62
# 3    2019       1979   649.0   73.0  32.25  54.82         1.10         1.79
# 4    2019       1979   138.0  259.0  38.24  40.45         1.57         1.24

# %%
y.unique()
# Out:
# array([1, 0])

# %%
X_train, X_valid, y_train, y_valid = train_test_split(trainX, y,test_size=0.2, random_state=0)

# %%
X_train.shape,y_train.shape
# Out:
# ((5954, 8), (5954,))

# %%
# def LR_modl():
#     model=LogisticRegression(solver='liblinear',penalty='l1', random_state=1,max_iter=100)
#     return model

# %%
# from xgboost import XGBClassifier

# %%
# def xgboost_model():
#     model=XGBClassifier(n_estimators=10000, eta=0.001,objective='binary:logistic')
#     return model

# %%
# model=xgboost_model()
# model.fit(X_train,y_train,eval_metric='logloss',early_stopping_rounds=20,eval_set=[[X_valid,y_valid]])

# %%
# from sklearn import svm
# def SVM_model():
#     model = svm.SVC(kernel='rbf',max_iter=-1)
#     return model

# %%
# from sklearn.linear_model import SGDClassifier
# def SGD_model():
#     clf = SGDClassifier(loss="hinge", penalty="l1", max_iter=500)
#     return clf

# %%
# model=SGD_model()
# model.fit(X_train,y_train)

# %%
import lightgbm as lgb
def LGBM_model():
    lgb_train = lgb.Dataset(X_train, y_train)
    lgb_valid = lgb.Dataset(X_valid, y_valid)
    params={}
    params['learning_rate']=0.01
    params['boosting_type']='goss' #GradientBoostingDecisionTree
    params['objective']='binary' #Binary target feature
    params['metric']='binary_logloss' #metric for binary classification
    params['max_depth']=12
    params['num_leaves']=60
    params['min_data_in_leaf']=20
    #params['extra_trees']=True
#     params['n_jobs']=3
    #params['early_stopping_round']=5
    #params['lambda_l2']=0.01
    num_round = 2450
    bst = lgb.train(params, lgb_train, num_round, valid_sets=[lgb_valid],early_stopping_rounds=100)
    #bst=lgb.cv(params, lgb_train, num_round, nfold=5)
    return bst

# %%
model=LGBM_model()
# Out:
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 4064, number of negative: 1890
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000144 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1466
# [LightGBM] [Info] Number of data points in the train set: 5954, number of used features: 8
# [LightGBM] [Info] Using GOSS
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.682566 -> initscore=0.765591
# [LightGBM] [Info] Start training from score 0.765591
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	valid_0's binary_logloss: 0.620863
# Training until validation scores don't improve for 100 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	valid_0's binary_logloss: 0.611614
# ...

# %%
model.params
# Out:
# {'learning_rate': 0.01,
#  'boosting_type': 'goss',
#  'objective': 'binary',
#  'metric': 'binary_logloss',
#  'max_depth': 12,
#  'num_leaves': 60,
#  'min_data_in_leaf': 20,
#  'num_iterations': 2450,
#  'early_stopping_round': 100}

# %%
pred=model.predict(X_valid)
pred1=pred.copy()
pred1
# Out:
# array([9.99440735e-01, 9.99860068e-01, 9.99858578e-01, ...,
#        9.96477553e-01, 9.26877626e-01, 3.32137928e-04])

# %%
pred=pred.round(0)
pred.astype(int)
pred
# Out:
# array([1., 1., 1., ..., 1., 1., 0.])

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_valid, pred)
print('Confusion matrix\n\n', cm)
print('\nTrue Positives(TP) = ', cm[0,0])
print('\nTrue Negatives(TN) = ', cm[1,1])
print('\nFalse Positives(FP) = ', cm[0,1])
print('\nFalse Negatives(FN) = ', cm[1,0])
# Out:
# Confusion matrix
#
#  [[ 477    6]
#  [   6 1000]]
#
# True Positives(TP) =  477
#
# True Negatives(TN) =  1000
#
# False Positives(FP) =  6
#
# False Negatives(FN) =  6

# %%
import seaborn as sns
cm_matrix = pd.DataFrame(data=cm, columns=['Actual Positive:1', 'Actual Negative:0'], 
                                 index=['Predict Positive:1', 'Predict Negative:0'])

sns.heatmap(cm_matrix, annot=True, fmt='d', cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %%
log_loss(y_valid,pred1)
# Out:
# 0.022306022381289693

# %%
f_pred=model.predict(testX)
#f_pred=f_pred.round(0)
#f_pred=f_pred.astype(int)
f_pred
# Out:
# array([9.99619887e-01, 9.99292858e-01, 6.93395413e-04, ...,
#        9.99209118e-01, 9.99862096e-01, 9.99081899e-01])

# %%
final=pd.read_csv("data/submission.csv")
final['Outcome']=f_pred


final.to_csv('submission.csv', index=False)
